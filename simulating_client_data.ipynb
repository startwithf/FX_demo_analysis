# %%
import pandas as pd

# %%
test_file = "raw_FX_data/DAT_ASCII_AUDCAD_M1_2024.csv"

df = pd.read_csv(
    test_file,
    sep=";",
    header=None,
    names=["datetime", "open", "high", "low", "close", "volume"],
)
df["datetime"] = pd.to_datetime(df["datetime"], format="%Y%m%d %H%M%S")

df.head()
# Out:
#              datetime     open     high      low    close  volume
# 0 2024-01-01 17:10:00  0.90091  0.90094  0.90082  0.90082       0
# 1 2024-01-01 17:11:00  0.90079  0.90079  0.90078  0.90079       0
# 2 2024-01-01 17:12:00  0.90084  0.90094  0.90035  0.90094       0
# 3 2024-01-01 17:13:00  0.90028  0.90072  0.90027  0.90071       0
# 4 2024-01-01 17:14:00  0.90072  0.90097  0.90066  0.90088       0
